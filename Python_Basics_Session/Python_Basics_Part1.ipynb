# %% [markdown]
# # Welcome to Python Basics and Documentation
#
# - This notebook involves various slides and Python Codes for better understanding.

# %% [markdown]
# <img src = "What.jpg" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "Why.jpg" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "Where.png" alt = "What is Python" height = "2000" width = "2140" />
#
# **https://github.com/kumar1987an/We_Learn_Python/blob/master/Python_footprints.md**

# %% [markdown]
# <img src = "HowStuffWorks.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "HowPythonWorks.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "Download.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "Run.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "Run1.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <img src = "Install.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# Downloaded from [https://www.python.org/downloads/](https://www.python.org/downloads/) along with Installation Instructions
#
# **Windows Installation** = Download .msi file for 32 or 64 bit versions and install, After installation, to start use below command in command prompt
# _```C:\> python or python3```_
#
# **Linux or Unix Installation** = Download zipped source code<br>
# extract the *.tar.gz file and go inside the extracted directory
# ```
# ./configure
# make
# makeinstall```
# Then run the command in shell _```$ python or python3```_
#
# **For Macintosh** = Please follow instructions to install and start python** _[https://docs.python-guide.org/starting/install3/osx/](https://docs.python-guide.org/starting/install3/osx/)_ <br>
#
# **<u>Other ways of Python**</u><br>
#
# _Python Jupyter notebooks ==> Notebooks for Python which is easy to interatively communicate with code by visualizations_<br>_Ipython ==> Interactive Python with less rich HTML content_<br>

# %% [markdown]
#
# <h1><font face= "Helvetica" color = #2a7bbd>Variables</font></h1>

# %% [markdown]
# **https://github.com/kumar1987an/We_Learn_Python/blob/master/Variable_Assigment.md**

# %%
# Code
# can consist of upper and lowercase letter, the digits 0-9 and the underscore character.

Name_of_the_Person_id200 = "John Smith"
print(Name_of_the_Person_id200)
# Out:
# John Smith

# %%
# the first character of a variable cannot be a digit

6inch_ladder = "Iron Ladder"
# Out:
#   File "/tmp/ipykernel_3370/227324216.py", line 3
#     6inch_ladder = "Iron Ladder"
#      ^
# SyntaxError: invalid syntax

# %%
# reserved keywords should not be used as variable names.

from keyword import kwlist
for words in kwlist:
    print(words, end=", ")
# Out:
# False, None, True, __peg_parser__, and, as, assert, async, await, break, class, continue, def, del, elif, else, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with, yield,

# %%
# are case-sensitive

laptop_brand = "Lenovo"
LAPTOP_BRAND = "HP"
Laptop_Brand = "DELL"
LAPtop_brand = "Acer"
print(laptop_brand, LAPTOP_BRAND, Laptop_Brand)
print(id(laptop_brand))
print(id(LAPTOP_BRAND))
print(id(Laptop_Brand))
print(id(LAPtop_brand))
# Out:
# Lenovo HP DELL
# 139713365450864
# 139713365454128
# 139713365453680
# 139713361915952

# %%
# Conventions as Defined in PEP8

# snake_case for functions and variable name

name_of_the_company = "LG"
employee_id = 8965362
html_request_page01 = "GET"
voice_tag_number = "78G66J2"

# dont used names looks like digits 1 and 0

Lexicans = "commit"
l0go_name = "DXC"

# Pascal case for class name

SchoolName = "ABC"
Alphabets = 'abcdefghijklmnopqrstuvwxyz'
FruitNames = "apple orange banana jackfruit grapes".split()

# Camel Case - Not recommended but no harm in using it

schoolName = "XYZ"
alphaNumeric = 'abcdefghijklmnopqrstuvwxyz0123456789'
inkColors = "blue green red black".split()
sCHoolName = "GGG"

# private variable

_age = 20

# Double underscores

__age__ = 78

# single underscores

_age_ = 3
# Out:
# 3

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Objects in Python</font></h1>

# %%
# Code

name_of_city = "New Jersey"
number_of_countries = 20
list_of_fruits = "apple orange grapes papaya".split()
tuple_of_numbers = (1, 2, 3, 4, 5, 6)
name_and_age = {"name": "Jack", "age": 22}
set_of_colors = {"red", "orange", "violet", "yellow"}
length_of_the_road = 6547.567

print(name_of_city)
print(type(name_of_city))
print(name_of_city.upper)
print()
print(number_of_countries)
print(type(number_of_countries))
print(number_of_countries.conjugate)
print()
print(list_of_fruits)
print(type(list_of_fruits))
print(list_of_fruits.append)
print()
print(tuple_of_numbers)
print(type(tuple_of_numbers))
print(tuple_of_numbers.count)
print()
print(name_and_age)
print(type(name_and_age))
print(name_and_age.keys)
print()
print(set_of_colors)
print(type(set_of_colors))
print(set_of_colors.add)
print()
print(length_of_the_road)
print(type(length_of_the_road))
print(length_of_the_road.fromhex)
# Out:
# New Jersey
# <class 'str'>
# <built-in method upper of str object at 0x7f118dba3470>
#
# 20
# <class 'int'>
# <built-in method conjugate of int object at 0x7f11b48a9b90>
#
# ['apple', 'orange', 'grapes', 'papaya']
# <class 'list'>
# <built-in method append of list object at 0x7f118d846300>
#
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
# <built-in method count of tuple object at 0x7f118d64c820>
#
# {'name': 'Jack', 'age': 22}
# <class 'dict'>
# <built-in method keys of dict object at 0x7f118dda7a00>
#
# {'yellow', 'orange', 'red', 'violet'}
# <class 'set'>
# <built-in method add of set object at 0x7f118d4f6ac0>
#
# 6547.567
# <class 'float'>
# <built-in method fromhex of type object at 0x90d480>

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Indentation</font></h1>

# %%
# Code

x = 22
# Condition checks
if x < 100:
    print(x)
    
# Functions
def f1(x):
    return x
print(f1(32))

# For and While Loops
for iteration in [1,2,3,4]:
    print(iteration, end=",")
    
print()

# Classes
class Fruitnames:
    pass

print(Fruitnames)

# Context Managers
with open("filename.txt", "w") as file_name:
    file_name.write("First Line\n")

# try, except, else, finally bloack
try:
    pass
except:
    pass
else:
    pass
finally:
    pass
# Out:
# 22
# 32
# 1,2,3,4,
# <class '__main__.Fruitnames'>

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Data Types</font></h1>

# %% [markdown]
# <img src = "Datatypes.png" alt = "What is Python" height = "2000" width = "2140" />

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Numbers</font></h1>

# %% [markdown]
# <img src = "numbers.png" alt = "What is Python" height = "2000" width = "2140" />

# %%
# Code
int_number = 78
float_number = 45.67e-4
complex_number = -45-22j
binary_number = b'100110'
hex_number = hex(int_number)
oct_number = oct(22)

print(int_number)
print(type(int_number))
print(float_number)
print(type(float_number))
print(complex_number)
print(type(complex_number))
print(binary_number)
print(type(binary_number))
print(hex_number)
print(type(hex_number))
print(oct_number)
print(type(oct_number))

# in python there is no limitation for the digit count, 
# it depends on the cpu architecture in general 64 bit so its infinte

large_number = 2e64
print(large_number)
# Out:
# 78
# <class 'int'>
# 0.004567
# <class 'float'>
# (-45-22j)
# <class 'complex'>
# b'100110'
# <class 'bytes'>
# 0x4e
# <class 'str'>
# 0o26
# <class 'str'>
# 2e+64

# %%
# Math function

import math

# print(dir(math))
print(math.sqrt(8787843878979879879797987987))
print(math.floor(4.55))
print(math.e)
print(math.pi)
print(math.tau)
print(math.sin(37884))
print(math.tan(274))
print(math.cos(744))
print(math.ceil(865.188888))
# Out:
# 93743500462591.44
# 4
# 2.718281828459045
# 3.141592653589793
# 6.283185307179586
# 0.44914632747405453
# 0.8110443877081378
# -0.8486021709533231
# 866

# %%
# PARANETHESIS, EXPONENT, MULTIPLICATION, DIVISION, ADDITION, AND SUBTRACTION
expression_1 = 22 + 646 * (27 - (22 / 2) + 8 / 7) + 0.56
expression_2 = round((60 + 10 * (20 - 2 / 18)) % 2) # % remainder
expression_3 = (60 + 10 * (20 - 2 / 18)) // 2 # % Quotient
print(expression_1)
print(expression_2)
print(expression_3)
# Out:
# 11096.845714285713
# 1
# 129.0

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Boolean</font></h1>

# %% [markdown]
# <img src = "bool.png" alt = "What is Python" height = "2000" width = "2140" />

# %%
# Code

# %% [markdown]
#  <h1><font face= "Helvetica" color = #2a7bbd>Strings</font></h1>

# %% [markdown]
# <img src = "strings.png" alt = "What is Python" height = "2000" width = "2140" />

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Lists</font></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Indexing, Slicing, Splitting

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Tuples</font></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Sets</font></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Dictionaries</font></h1>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Condition Expressions</font></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Comparison Operators</font></h1>

# %% [markdown]
# These Operators will allow us to compare variables and output a Boolean value (True or False)
#
# ### Table of Comparison Operators
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td>(a != b) is true</td>
# </tr>
# <tr>
# <td>&lt;&gt;</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td> (a &lt;&gt; b) is true. This is similar to != operator.</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Loops</font></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Code

# %% [markdown]
# <h1><font face= "Helvetica" color = #2a7bbd>Built-In-Functions</font></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Code
